# %%
# Dependencies
import os
import requests
import ssl
from bs4 import BeautifulSoup as bs
import urllib.request, urllib.parse, urllib.error
#import warnings if not sys.warnoptions:
    #warnings.simplefilter("ignore")#For ignoring SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE# url = input('Enter url - ' )

# %%
# URL of page to be scraped
# check in 04-01-2019 check out 04-30-2019
url = 'https://www.vrbo.com/results?adultsCount=1&petIncluded=false&q=Honolulu%2C%20HI%2C%20USA&from-date=2019-04-01&to-date=2019-04-06'

# %%
html = urllib.request.urlopen(url, context=ctx).read()

# %%
soup = bs(html, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
html = soup.prettify("utf-8")

# %%
# hotel names
name_results = soup.find_all("h4")
name_results
# Out:
# [<h4 class="HitInfo__headline hover-text hidden-xs" href="/738346">Hawaiian Monarch -Studio with Canal View/Partial Ocean View/Wifi</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/875569">Fresh Renovated Inn on the Park Studio near Beach with Park &amp; Ocean Views!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/4476630ha">1009 KING BED Modern/Waikiki Beach</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/748231">Fully Renovated Condo by Ocean with Full Kitchen in Boutique Style Building</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/895883">Spacious 1BR with 180-Degree Ocean Views! Prime Waikiki Location!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/737390">((( Ocean Views! ))) Newly Upgraded Studio!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1058467">Waikiki Grand - Diamond Head &amp; Ocean Views, Kitchenette &amp; Lanai Free WiFi</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1333863">Fairway Villa 804 / Studio - Free Wifi, TV &amp; Parking</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/808936">Grand Opening Discount - Renovated Studio - Awesome Unobstructed Ocean Views</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/748317">Easy Access to Amazing Beaches in this Beautiful Condo by the Sea</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/4850820ha">Brand New Waikiki Diamond Head Favorite</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/83193">Wyndham Royal Garden Waikiki - Free WIFI In Room - Beautiful Views</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1192887">New Listing! Modern Condo on the 29th Floor in Waikiki with Incredible Views</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1325981">Charming Beachfront Studio at Waikiki Shore</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1062922">Paradise Dream in Hawaii 天堂之夢</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/474694">Ocean View Penthouse Studio By The Beach With Huge Lanai And Great Amenities</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1239830">Diamond Head Beach - Queen Studio with Balcony - Ocean View</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/111945">BEST VALUE downtown Honolulu Executive Centre ocean view parking included</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1187502">Waikiki Hotel Studio @ Hawaiian Monarch Hotel Building</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/4869503ha">Cozy Downtown Honolulu Apt w/ Pool Access by HPU!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1200158">Beautiful Studio in the Heart of Waikiki | Ocean Views | 1 Block from Beach</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1190536">Ocean View Studio In Fabulous Waikiki Beach, Just Remodeled, On The 25th Floor</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/4854010ha">Brand New Waikiki Vacation Promenade at Diamond Head</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/900188ha">Waikiki Grand Grand Across from Zoo, Shopping,Waikiki Beach</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1196899">Modern Waikiki Remodeled Condo--Incredible View, Perfect Location Near the Beach</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1275922">Aloha Suite Near the Sea II, 3 Min Walk to Beach</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/511369">Stylish studio, kitchen, city/mtn views, close to everything! Sleeps 2.</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/4540823ha">Center of Waikiki Renovated Ocean View Condo(MS03)</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/393783">Cozy Waikiki Condo Steps to Beaches, Private Lanai and Partial Ocean Views</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1128924">Ocean front Studio with Breathtaking Views, Book Now at Special Nightly Rate!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/4965815ha">Spectacular Direct Ocean Front with Ocean Views From Every Room!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/418892">Ocean View End unit Royal Kuhio Condo, Great Amenities, Free Parking!!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/4301807ha">Park-Front Waikiki Studio - Near Beach w/ Views!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1296226">Waikiki Fairway Villa</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/145024">Bamboo Hotel - Queen Studio with Balcony - Steps to Waikiki Beach</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1189226">Elegant 1 Bedroom Bungalow for 4</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1343569">Newly renovated and clean studio in Waikiki for two with amazing views</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1058580">Great ocean view 1BR - 2min from the Beach with Hawaiian decoハワイアンスタイルの海が見えるお部屋</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/4849941ha">New! Kalihi valley affordable private room E with shared bathroom</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/625371">Deluxe one bedroom with kitchen, washer/dryer, WiFi, one parking</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/748348">Charming Condo by the Beach a Short Stroll to Dining and Attractions</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/748316">Tropical Royal Moana 1BR Condo VERY Close Walk to Beaches, Shopping, Dining</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1295610">Paradise Studio in Manoa Hawaii</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/788826">Affordable Comfort - Mountain View, Corner Studio</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/805225">Cute Hideaway for 2 in Lovely Manoa Valley</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/308603">Elegance Redefined - Your Waikiki Dream Vacation at Affordable Price</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/748322">AMAZING Waikiki Skytower Condo - Close Walk to Everything!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1257988">Newly Renovated Four Paddle Condo, Close Walk to Beaches, Free Parking!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/4587056ha">Renovated Waikiki Condo - Steps from the Beach!</h4>,
#  <h4 class="HitInfo__headline hover-text hidden-xs" href="/1143374">Just Remodeled Studio Condo, Modern, Clean--View!</h4>,
#  <h4>Recent Honolulu Reviews</h4>]

# %%
# loop through returned results
rental_names = []
for result in name_results:
    # Error handling
    try:
        # Identify and return name of hotel
        name = result.text
        
        # Print results only if title, price, and link are available
        if (name):
            print('-------------')
            print(name)
            rental_names.append(name)
    except AttributeError as e:
        print(e)
# Out:
# -------------
# Hawaiian Monarch -Studio with Canal View/Partial Ocean View/Wifi
# -------------
# Fresh Renovated Inn on the Park Studio near Beach with Park & Ocean Views!
# -------------
# 1009 KING BED Modern/Waikiki Beach
# -------------
# Fully Renovated Condo by Ocean with Full Kitchen in Boutique Style Building
# -------------
# Spacious 1BR with 180-Degree Ocean Views! Prime Waikiki Location!
# -------------
# ((( Ocean Views! ))) Newly Upgraded Studio!
# -------------
# Waikiki Grand - Diamond Head & Ocean Views, Kitchenette & Lanai Free WiFi
# -------------
# Fairway Villa 804 / Studio - Free Wifi, TV & Parking
# -------------
# Grand Opening Discount - Renovated Studio - Awesome Unobstructed Ocean Views
# -------------
# Easy Access to Amazing Beaches in this Beautiful Condo by the Sea
# -------------
# Brand New Waikiki Diamond Head Favorite
# -------------
# Wyndham Royal Garden Waikiki - Free WIFI In Room - Beautiful Views
# -------------
# New Listing! Modern Condo on the 29th Floor in Waikiki with Incredible Views
# -------------
# Charming Beachfront Studio at Waikiki Shore
# -------------
# Paradise Dream in Hawaii 天堂之夢
# -------------
# Ocean View Penthouse Studio By The Beach With Huge Lanai And Great Amenities
# -------------
# Diamond Head Beach - Queen Studio with Balcony - Ocean View
# -------------
# BEST VALUE downtown Honolulu Executive Centre ocean view parking included
# -------------
# Waikiki Hotel Studio @ Hawaiian Monarch Hotel Building
# -------------
# Cozy Downtown Honolulu Apt w/ Pool Access by HPU!
# -------------
# Beautiful Studio in the Heart of Waikiki | Ocean Views | 1 Block from Beach
# -------------
# Ocean View Studio In Fabulous Waikiki Beach, Just Remodeled, On The 25th Floor
# -------------
# Brand New Waikiki Vacation Promenade at Diamond Head
# -------------
# Waikiki Grand Grand Across from Zoo, Shopping,Waikiki Beach
# -------------
# Modern Waikiki Remodeled Condo--Incredible View, Perfect Location Near the Beach
# -------------
# Aloha Suite Near the Sea II, 3 Min Walk to Beach
# -------------
# Stylish studio, kitchen, city/mtn views, close to everything! Sleeps 2.
# -------------
# Center of Waikiki Renovated Ocean View Condo(MS03)
# -------------
# Cozy Waikiki Condo Steps to Beaches, Private Lanai and Partial Ocean Views
# -------------
# Ocean front Studio with Breathtaking Views, Book Now at Special Nightly Rate!
# -------------
# Spectacular Direct Ocean Front with Ocean Views From Every Room!
# -------------
# Ocean View End unit Royal Kuhio Condo, Great Amenities, Free Parking!!
# -------------
# Park-Front Waikiki Studio - Near Beach w/ Views!
# -------------
# Waikiki Fairway Villa
# -------------
# Bamboo Hotel - Queen Studio with Balcony - Steps to Waikiki Beach
# -------------
# Elegant 1 Bedroom Bungalow for 4
# -------------
# Newly renovated and clean studio in Waikiki for two with amazing views
# -------------
# Great ocean view 1BR - 2min from the Beach with Hawaiian decoハワイアンスタイルの海が見えるお部屋
# -------------
# New! Kalihi valley affordable private room E with shared bathroom
# -------------
# Deluxe one bedroom with kitchen, washer/dryer, WiFi, one parking
# -------------
# Charming Condo by the Beach a Short Stroll to Dining and Attractions
# -------------
# Tropical Royal Moana 1BR Condo VERY Close Walk to Beaches, Shopping, Dining
# -------------
# Paradise Studio in Manoa Hawaii
# -------------
# Affordable Comfort - Mountain View, Corner Studio
# -------------
# Cute Hideaway for 2 in Lovely Manoa Valley
# -------------
# Elegance Redefined - Your Waikiki Dream Vacation at Affordable Price
# -------------
# AMAZING Waikiki Skytower Condo - Close Walk to Everything!
# -------------
# Newly Renovated Four Paddle Condo, Close Walk to Beaches, Free Parking!
# -------------
# Renovated Waikiki Condo - Steps from the Beach!
# -------------
# Just Remodeled Studio Condo, Modern, Clean--View!
# -------------
# Recent Honolulu Reviews

# %%
# hotel prices
prices_results = soup.find_all("span", class_="PriceSummary__amount")
prices_results
# Out:
# [<span class="PriceSummary__amount">$85</span>,
#  <span class="PriceSummary__amount">$75</span>,
#  <span class="PriceSummary__amount">$90</span>,
#  <span class="PriceSummary__amount">$85</span>,
#  <span class="PriceSummary__amount">$120</span>,
#  <span class="PriceSummary__amount">$90</span>,
#  <span class="PriceSummary__amount">$118</span>,
#  <span class="PriceSummary__amount">$135</span>,
#  <span class="PriceSummary__amount">$125</span>,
#  <span class="PriceSummary__amount">$99</span>,
#  <span class="PriceSummary__amount">$94</span>,
#  <span class="PriceSummary__amount">$110</span>,
#  <span class="PriceSummary__amount">$99</span>,
#  <span class="PriceSummary__amount">$180</span>,
#  <span class="PriceSummary__amount">$108</span>,
#  <span class="PriceSummary__amount">$82</span>,
#  <span class="PriceSummary__amount">$135</span>,
#  <span class="PriceSummary__amount">$160</span>,
#  <span class="PriceSummary__amount">$75</span>,
#  <span class="PriceSummary__amount">$96</span>,
#  <span class="PriceSummary__amount">$114</span>,
#  <span class="PriceSummary__amount">$110</span>,
#  <span class="PriceSummary__amount">$89</span>,
#  <span class="PriceSummary__amount">$85</span>,
#  <span class="PriceSummary__amount">$99</span>,
#  <span class="PriceSummary__amount">$104</span>,
#  <span class="PriceSummary__amount">$105</span>,
#  <span class="PriceSummary__amount">$110</span>,
#  <span class="PriceSummary__amount">$85</span>,
#  <span class="PriceSummary__amount">$120</span>,
#  <span class="PriceSummary__amount">$175</span>,
#  <span class="PriceSummary__amount">$117</span>,
#  <span class="PriceSummary__amount">$75</span>,
#  <span class="PriceSummary__amount">$99</span>,
#  <span class="PriceSummary__amount">$104</span>,
#  <span class="PriceSummary__amount">$79</span>,
#  <span class="PriceSummary__amount">$99</span>,
#  <span class="PriceSummary__amount">$139</span>,
#  <span class="PriceSummary__amount">$79</span>,
#  <span class="PriceSummary__amount">$115</span>,
#  <span class="PriceSummary__amount">$89</span>,
#  <span class="PriceSummary__amount">$98</span>,
#  <span class="PriceSummary__amount">$99</span>,
#  <span class="PriceSummary__amount">$99</span>,
#  <span class="PriceSummary__amount">$99</span>,
#  <span class="PriceSummary__amount">$119</span>,
#  <span class="PriceSummary__amount">$129</span>,
#  <span class="PriceSummary__amount">$118</span>,
#  <span class="PriceSummary__amount">$143</span>,
#  <span class="PriceSummary__amount">$99</span>]

# %%
# loop through returned results
rental_prices = []
for result in prices_results:
    # Error handling
    try:
        # Identify and return name of hotel
        price = result.text
        
        # Print results only if title, price, and link are available
        if (price):
            print('-------------')
            print(price)
            rental_prices.append(price)
    except AttributeError as e:
        print(e)
# Out:
# -------------
# $85
# -------------
# $75
# -------------
# $90
# -------------
# $85
# -------------
# $120
# -------------
# $90
# -------------
# $118
# -------------
# $135
# -------------
# $125
# -------------
# $99
# -------------
# $94
# -------------
# $110
# -------------
# $99
# -------------
# $180
# -------------
# $108
# -------------
# $82
# -------------
# $135
# -------------
# $160
# -------------
# $75
# -------------
# $96
# -------------
# $114
# -------------
# $110
# -------------
# $89
# -------------
# $85
# -------------
# $99
# -------------
# $104
# -------------
# $105
# -------------
# $110
# -------------
# $85
# -------------
# $120
# -------------
# $175
# -------------
# $117
# -------------
# $75
# -------------
# $99
# -------------
# $104
# -------------
# $79
# -------------
# $99
# -------------
# $139
# -------------
# $79
# -------------
# $115
# -------------
# $89
# -------------
# $98
# -------------
# $99
# -------------
# $99
# -------------
# $99
# -------------
# $119
# -------------
# $129
# -------------
# $118
# -------------
# $143
# -------------
# $99

# %%
rental_prices
# Out:
# ['$85',
#  '$75',
#  '$90',
#  '$85',
#  '$120',
#  '$90',
#  '$118',
#  '$135',
#  '$125',
#  '$99',
#  '$94',
#  '$110',
#  '$99',
#  '$180',
#  '$108',
#  '$82',
#  '$135',
#  '$160',
#  '$75',
#  '$96',
#  '$114',
#  '$110',
#  '$89',
#  '$85',
#  '$99',
#  '$104',
#  '$105',
#  '$110',
#  '$85',
#  '$120',
#  '$175',
#  '$117',
#  '$75',
#  '$99',
#  '$104',
#  '$79',
#  '$99',
#  '$139',
#  '$79',
#  '$115',
#  '$89',
#  '$98',
#  '$99',
#  '$99',
#  '$99',
#  '$119',
#  '$129',
#  '$118',
#  '$143',
#  '$99']

# %%
rental_names
# Out:
# ['Hawaiian Monarch -Studio with Canal View/Partial Ocean View/Wifi',
#  'Fresh Renovated Inn on the Park Studio near Beach with Park & Ocean Views!',
#  '1009 KING BED Modern/Waikiki Beach',
#  'Fully Renovated Condo by Ocean with Full Kitchen in Boutique Style Building',
#  'Spacious 1BR with 180-Degree Ocean Views! Prime Waikiki Location!',
#  '((( Ocean Views! ))) Newly Upgraded Studio!',
#  'Waikiki Grand - Diamond Head & Ocean Views, Kitchenette & Lanai Free WiFi',
#  'Fairway Villa 804 / Studio - Free Wifi, TV & Parking',
#  'Grand Opening Discount - Renovated Studio - Awesome Unobstructed Ocean Views',
#  'Easy Access to Amazing Beaches in this Beautiful Condo by the Sea',
#  'Brand New Waikiki Diamond Head Favorite',
#  'Wyndham Royal Garden Waikiki - Free WIFI In Room - Beautiful Views',
#  'New Listing! Modern Condo on the 29th Floor in Waikiki with Incredible Views',
#  'Charming Beachfront Studio at Waikiki Shore',
#  'Paradise Dream in Hawaii 天堂之夢',
#  'Ocean View Penthouse Studio By The Beach With Huge Lanai And Great Amenities',
#  'Diamond Head Beach - Queen Studio with Balcony - Ocean View',
#  'BEST VALUE downtown Honolulu Executive Centre ocean view parking included',
#  'Waikiki Hotel Studio @ Hawaiian Monarch Hotel Building',
#  'Cozy Downtown Honolulu Apt w/ Pool Access by HPU!',
#  'Beautiful Studio in the Heart of Waikiki | Ocean Views | 1 Block from Beach',
#  'Ocean View Studio In Fabulous Waikiki Beach, Just Remodeled, On The 25th Floor',
#  'Brand New Waikiki Vacation Promenade at Diamond Head',
#  'Waikiki Grand Grand Across from Zoo, Shopping,Waikiki Beach',
#  'Modern Waikiki Remodeled Condo--Incredible View, Perfect Location Near the Beach',
#  'Aloha Suite Near the Sea II, 3 Min Walk to Beach',
#  'Stylish studio, kitchen, city/mtn views, close to everything! Sleeps 2.',
#  'Center of Waikiki Renovated Ocean View Condo(MS03)',
#  'Cozy Waikiki Condo Steps to Beaches, Private Lanai and Partial Ocean Views',
#  'Ocean front Studio with Breathtaking Views, Book Now at Special Nightly Rate!',
#  'Spectacular Direct Ocean Front with Ocean Views From Every Room!',
#  'Ocean View End unit Royal Kuhio Condo, Great Amenities, Free Parking!!',
#  'Park-Front Waikiki Studio - Near Beach w/ Views!',
#  'Waikiki Fairway Villa',
#  'Bamboo Hotel - Queen Studio with Balcony - Steps to Waikiki Beach',
#  'Elegant 1 Bedroom Bungalow for 4',
#  'Newly renovated and clean studio in Waikiki for two with amazing views',
#  'Great ocean view 1BR - 2min from the Beach with Hawaiian decoハワイアンスタイルの海が見えるお部屋',
#  'New! Kalihi valley affordable private room E with shared bathroom',
#  'Deluxe one bedroom with kitchen, washer/dryer, WiFi, one parking',
#  'Charming Condo by the Beach a Short Stroll to Dining and Attractions',
#  'Tropical Royal Moana 1BR Condo VERY Close Walk to Beaches, Shopping, Dining',
#  'Paradise Studio in Manoa Hawaii',
#  'Affordable Comfort - Mountain View, Corner Studio',
#  'Cute Hideaway for 2 in Lovely Manoa Valley',
#  'Elegance Redefined - Your Waikiki Dream Vacation at Affordable Price',
#  'AMAZING Waikiki Skytower Condo - Close Walk to Everything!',
#  'Newly Renovated Four Paddle Condo, Close Walk to Beaches, Free Parking!',
#  'Renovated Waikiki Condo - Steps from the Beach!',
#  'Just Remodeled Studio Condo, Modern, Clean--View!',
#  'Recent Honolulu Reviews']
